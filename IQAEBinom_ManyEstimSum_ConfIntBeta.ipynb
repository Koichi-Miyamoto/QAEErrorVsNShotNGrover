# %%
import numpy as np
from IQAEBinom import IQAEBinom
import matplotlib.pyplot as plt

# %%
epsilon = 0.001
nEstim = 1000
alpha = 0.05 / np.sqrt(nEstim)
nShotUnit = 1

# %%
pTrue = 0.1
errors = []
for i in range(nEstim):
    result = IQAEBinom(pTrue, epsilon, alpha, nShotUnit, confint_method="beta")
    errors.append(result['Estimate'] - pTrue)

plt.xlabel('IdEstim')
plt.ylabel('CumErr')

# 描画
ax = plt.gca()
plt.plot(np.arange(nEstim), np.array(errors).cumsum())

ax.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
errors
# Out:
# [-7.058382687546993e-05,
#  -7.658510668971663e-05,
#  -5.555424978484491e-05,
#  0.0002184866944467262,
#  0.00011437507647019118,
#  2.7937477171738334e-05,
#  0.0005518759445141824,
#  8.985918339740606e-05,
#  -2.765506481354485e-05,
#  -8.249646350627637e-07,
#  4.666066033366667e-05,
#  7.073976611862709e-05,
#  0.0002534388359827777,
#  0.00027861829824940565,
#  -4.374016728403429e-05,
#  7.271576571725447e-05,
#  8.985918339740606e-05,
#  -9.847525292035197e-05,
#  0.0002130560255445696,
#  0.00010161098840176519,
#  -3.462649875024537e-05,
#  -0.00010817882126824829,
#  -0.0002530574104447486,
#  4.8147262646125455e-05,
#  9.715613799865519e-06,
#  -0.00028940661156368064,
#  -7.709898704386098e-05,
#  0.00011437507647019118,
#  9.715613799865519e-06,
#  0.00012073626800972181,
#  -0.00017074708181878673,
#  0.00010161098840176519,
#  -3.081685451278293e-05,
#  0.0002184866944467262,
#  -9.564127487357577e-05,
#  0.0002018531504899279,
#  1.7523923138557107e-05,
# ...

# %%
result
# Out:
# {'Estimate': 0.09994672686005408,
#  'nGrover': [0, 1, 3, 8, 18, 42, 91, 186],
#  'nShots': [188, 46, 53, 43, 38, 28, 26, 22],
#  'n1s': [20, 34, 31, 24, 12, 18, 11, 7],
#  'thetaIntervals': [[0, 1.5707963267948966],
#   [0.17070385747689998, 0.5230227431485713],
#   [0.22586297565870975, 0.44825517589185754],
#   [0.2820666390337737, 0.36845406717197127],
#   [0.30137268431614084, 0.3391110249315885],
#   [0.31422726213077984, 0.33189455617926794],
#   [0.31762456006196643, 0.32612557382791185],
#   [0.3203054270349499, 0.32422177561469395],
#   [0.32072719272145217, 0.322710969453647]],
#  'ampSqIntervals': [[0, 1],
#   [0.028857861596608178, 0.249501307282157],
#   [0.050152483892705935, 0.18783014339660245],
#   [0.077473830117202, 0.12972508334864769],
#   [0.08810882258673772, 0.11065527409491117],
#   [0.09553147405261034, 0.10616830134207478],
#   [0.09753805048130523, 0.10264029070067074],
#   [0.0991345955034919, 0.10148761223170578],
# ...

# %%
pTrue = 0.001
errors = []
for _ in range(nEstim):
    result = IQAEBinom(pTrue, epsilon, alpha, nShotUnit, confint_method="beta")
    errors.append(result['Estimate'] - pTrue)

plt.xlabel('IdEstim')
plt.ylabel('CumErr')

# 描画
ax = plt.gca()
plt.plot(np.arange(nEstim), np.array(errors).cumsum())

ax.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
errors
# Out:
# [0.00021305079606861424,
#  0.00015782511957251042,
#  2.1911208612741774e-05,
#  0.00031165087563437524,
#  0.00015782511957251042,
#  2.1911208612741774e-05,
#  2.1911208612741774e-05,
#  0.00024071527712210398,
#  2.1911208612741774e-05,
#  0.00012469736632734,
#  6.968938992973645e-07,
#  -0.0001904401800726979,
#  0.0004560683772896221,
#  -0.00013524759993265316,
#  -0.00010890895600527018,
#  -0.00014500000804349236,
#  7.964701121155986e-05,
#  2.1911208612741774e-05,
#  2.1911208612741774e-05,
#  0.0004560683772896221,
#  -3.417784675804696e-05,
#  2.1911208612741774e-05,
#  -0.00010890895600527018,
#  0.0004560683772896221,
#  2.1911208612741774e-05,
#  -0.00010890895600527018,
#  -0.00013524759993265316,
#  -9.653056334134455e-05,
#  -0.00013524759993265316,
#  7.964701121155986e-05,
#  -5.063373637683691e-05,
#  7.964701121155986e-05,
#  0.00024071527712210398,
#  -9.653056334134455e-05,
#  7.964701121155986e-05,
#  2.1911208612741774e-05,
#  -3.417784675804696e-05,
# ...

# %%
result
# Out:
# {'Estimate': 0.0010219112086127418,
#  'nGrover': [0, 1, 3, 7, 15],
#  'nShots': [50, 33, 21, 48, 40],
#  'n1s': [0, 1, 0, 8, 28],
#  'thetaIntervals': [[0, 1.5707963267948966],
#   [0.0, 0.5206496162084726],
#   [8.233074649632898e-05, 0.22414324199782695],
#   [0.0, 0.10396095536603099],
#   [0.009969794622730687, 0.050423496140887945],
#   [0.02103072921727448, 0.04178911863052933]],
#  'ampSqIntervals': [[0, 1],
#   [0.0, 0.24745031661580627],
#   [6.778351803327435e-09, 0.0494044497628794],
#   [0.0, 0.010768999548733468],
#   [9.939351162147166e-05, 0.0025403748755863788],
#   [0.00044222636797757136, 0.0017453141159223069]]}

# %%
# pTrue = 0.001
# nTrial = 10
# errorCumSeqs = []

# for _ in range(nTrial):
#     errors = []
#     for _ in range(nEstim):
#         result = IQAEBinom(pTrue, epsilon, alpha, nShotUnit, confint_method="beta")
#         errors.append(result['Estimate'] - pTrue)

#     errorCumSeqs.append(np.array(errors).cumsum())

# plt.xlabel('IdEstim')
# plt.ylabel('CumErr')

# for i in range(nTrial):
#     ax = plt.gca()
#     plt.plot(np.arange(nEstim), errorCumSeqs[i])

# ax.legend()
# plt.show()

# %%
# np.savetxt('C:/Users/koich/Desktop/Code/QAEErrorVsNShotNGrover/output/cumerrIQAE_pTrue0.001_eps0.001_alphaTot0.05_alphaPropNEstSqInv.csv', np.array(errorCumSeqs).T, delimiter=',')
