# %%
import numpy as np
from BiasCorrection import BiasCoxSnell, BiasExact, BiasCordeiroKlein
import matplotlib.pyplot as plt
import pickle

# %%
nGrover = 100
nShot = 50

# %%
ampSq = 0.2
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
print(BiasCordeiroKlein(ampSq, nGrover, nShot))
# Out:
# -1.239942334925843e-05
# -1.1923485143504643e-05
# -1.1700718380305715e-05

# %%
ampSq = 0.1
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
print(BiasCordeiroKlein(ampSq, nGrover, nShot))
# Out:
# -3.274645834642958e-05
# -2.5038013004741455e-05
# -2.4740990653809545e-05

# %%
ampSq = 0.1
nShot = 1000
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
print(BiasCordeiroKlein(ampSq, nGrover, nShot))
# Out:
# -1.2527052699635604e-06
# -1.251900650237073e-06
# -1.2370495326904772e-06

# %%
ampSq = 0.3
nShot = 1000
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
print(BiasCordeiroKlein(ampSq, nGrover, nShot))
# Out:
# -1.9235354692378504e-06
# -1.9145650304348018e-06
# -1.9071394716615046e-06

# %%
ampSq = 0.6
nShot = 10000
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
print(BiasCordeiroKlein(ampSq, nGrover, nShot))
# Out:
# -4.7086005436971176e-08
# -4.6891693410899976e-08
# -4.726297134956487e-08

# %%
ampSq = 0.95
nShot = 50
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
# Out:
# -3.4595036862553005e-05
# -2.2402685423407214e-05

# %%
ampSq = 0.95
nShot = 100
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
# Out:
# -1.3142072049069963e-05
# -1.1201342711703607e-05

# %%
ampSq = 0.95
nShot = 1000
print(BiasExact(ampSq, nGrover, nShot))
print(BiasCoxSnell(ampSq, nGrover, nShot))
# Out:
# -1.1390256715080284e-06
# -1.1201342711703606e-06
