# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from matplotlib.ticker import ScalarFormatter

# %%
nShotUnit = 1
epsilon = 0.001
alpha = 0.05

# %%
pTrue = 0.2505
thetaTrue = np.arcsin(np.sqrt(pTrue))

# %%
resDf = pd.read_csv("C:/Users/koich/Desktop/Code/QAEErrorVsNShotNGrover/output/20230914_Bias_VariousNGrovAngleFrac/Bias_VariousNGrovAngleFrac_p0.2505.csv")

# %%
resDf[resDf['nGrover'] == 300]
# Out:
#       nGrover      r  AngleFrac          Bias  NumSamp   NumEnd
# 1800    300.0  100.0   0.024390 -6.898673e-05  10000.0  10000.0
# 1801    300.0  100.0   0.048780 -7.059000e-05  10000.0  10000.0
# 1802    300.0  100.0   0.073171 -4.162464e-05  10000.0  10000.0
# 1803    300.0  100.0   0.097561 -1.060669e-05  10000.0  10000.0
# 1804    300.0  100.0   0.121951  4.693590e-07  10000.0  10000.0
# 1805    300.0  100.0   0.146341 -1.504399e-05  10000.0  10000.0
# 1806    300.0  100.0   0.170732 -2.423767e-05  10000.0  10000.0
# 1807    300.0  100.0   0.195122 -2.952179e-05  10000.0  10000.0
# 1808    300.0  100.0   0.219512 -2.709955e-05  10000.0  10000.0
# 1809    300.0  100.0   0.243902 -8.712436e-06  10000.0  10000.0
# 1810    300.0  100.0   0.268293  1.458024e-05  10000.0  10000.0
# 1811    300.0  100.0   0.292683  3.494976e-05  10000.0  10000.0
# 1812    300.0  100.0   0.317073  3.254054e-05  10000.0  10000.0
# 1813    300.0  100.0   0.341463  2.309008e-05  10000.0  10000.0
# 1814    300.0  100.0   0.365854  7.184543e-06  10000.0  10000.0
# 1815    300.0  100.0   0.390244  4.323896e-06  10000.0  10000.0
# 1816    300.0  100.0   0.414634  2.330097e-05  10000.0  10000.0
# 1817    300.0  100.0   0.439024  5.607630e-05  10000.0  10000.0
# 1818    300.0  100.0   0.463415  7.989122e-05  10000.0  10000.0
# 1819    300.0  100.0   0.487805  4.539632e-05  10000.0  10000.0
# 1820    300.0  100.0   0.512195  5.184665e-04  10000.0    127.0
# 1821    300.0  100.0   0.536585  4.193411e-04  10000.0   1119.0
# 1822    300.0  100.0   0.560976  3.202977e-04  10000.0   2766.0
# 1823    300.0  100.0   0.585366  2.274098e-04  10000.0   4756.0
# 1824    300.0  100.0   0.609756  1.465435e-04  10000.0   6576.0
# 1825    300.0  100.0   0.634146  7.570042e-05  10000.0   8131.0
# 1826    300.0  100.0   0.658537  1.788733e-05  10000.0   8967.0
# 1827    300.0  100.0   0.682927 -1.163022e-05  10000.0   9569.0
# 1828    300.0  100.0   0.707317 -2.284651e-05  10000.0   9856.0
# 1829    300.0  100.0   0.731707 -1.230791e-05  10000.0   9943.0
# 1830    300.0  100.0   0.756098  9.916164e-06  10000.0   9976.0
# 1831    300.0  100.0   0.780488  2.346216e-05  10000.0   9983.0
# 1832    300.0  100.0   0.804878  3.182481e-05  10000.0   9908.0
# 1833    300.0  100.0   0.829268  9.617282e-06  10000.0   9750.0
# 1834    300.0  100.0   0.853659 -2.572955e-05  10000.0   9306.0
# 1835    300.0  100.0   0.878049 -8.425642e-05  10000.0   8386.0
# 1836    300.0  100.0   0.902439 -1.570960e-04  10000.0   6798.0
# 1837    300.0  100.0   0.926829 -2.439163e-04  10000.0   4671.0
# 1838    300.0  100.0   0.951220 -3.393031e-04  10000.0   2420.0
# 1839    300.0  100.0   0.975610 -4.342034e-04  10000.0    693.0

# %%
plt.rcParams["font.size"] = 15
for nG in [200, 300, 400, 500]:
    ax = plt.gca()
    resDfPart = resDf[resDf["nGrover"] == nG]
    resDfPart.loc[resDfPart["NumEnd"] < 1000, "Bias"] = None
    plt.plot(resDfPart["AngleFrac"], resDfPart["Bias"], marker="o")
    ax.set_xlim((0,1))
    ax.set_ylim((-5e-4,5e-4))
    ax.set_xlabel("$f_{fin}$")
    ax.set_ylabel("Bias")
    #plt.yticks(np.arange(-5e-4, 5.1e-4, 1e-4))
    ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    ax.ticklabel_format(style="sci",  axis="y",scilimits=(0,0))
    plt.show()
# Out:
# c:\Users\koich\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# c:\Users\koich\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# c:\Users\koich\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# c:\Users\koich\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
