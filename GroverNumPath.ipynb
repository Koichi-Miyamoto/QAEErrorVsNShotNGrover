# %%
import pickle

# %%
f = open("C:/Users/koich/Desktop/Code/QAEErrorVsNShotNGrover/output/20230823_IQAE/resultMat_minRatio1.1to3.dat","rb")
resultMat = pickle.load(f)

# %%
len(resultMat)
# Out:
# 100

# %%
import numpy as np

# %%
np.geomspace(1.1, 3, 100)
# Out:
# array([1.1       , 1.11120448, 1.12252309, 1.13395699, 1.14550735,
#        1.15717536, 1.16896223, 1.18086915, 1.19289735, 1.20504808,
#        1.21732256, 1.22972208, 1.24224789, 1.2549013 , 1.26768358,
#        1.28059607, 1.29364008, 1.30681696, 1.32012806, 1.33357474,
#        1.34715839, 1.36088039, 1.37474217, 1.38874515, 1.40289076,
#        1.41718045, 1.43161569, 1.44619798, 1.46092879, 1.47580965,
#        1.49084209, 1.50602765, 1.52136788, 1.53686437, 1.5525187 ,
#        1.56833249, 1.58430735, 1.60044494, 1.61674689, 1.6332149 ,
#        1.64985065, 1.66665585, 1.68363223, 1.70078152, 1.7181055 ,
#        1.73560593, 1.75328463, 1.77114339, 1.78918407, 1.8074085 ,
#        1.82581857, 1.84441616, 1.86320318, 1.88218156, 1.90135326,
#        1.92072024, 1.94028449, 1.96004801, 1.98001285, 2.00018105,
#        2.02055467, 2.04113582, 2.06192661, 2.08292917, 2.10414566,
#        2.12557826, 2.14722917, 2.16910061, 2.19119484, 2.21351411,
# ...

# %%
np.geomspace(1.1, 3, 100)[59]
# Out:
# 2.0001810455303795

# %%
results = resultMat[59] # results for minRatio = 2.0001810455303795

# %%
import matplotlib.pyplot as plt

# %%
ax = plt.gca()

for r in results:
    plt.plot(r["nGrover"][1:])

plt.yscale("log")
plt.show()

# %%
plt.hist([r["nGrover"][1] for r in results])
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 100.,   0.,   0.,   0.,   0.]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist([r["nGrover"][2] for r in results])
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 100.,   0.,   0.,   0.,   0.]),
#  array([2.5, 2.6, 2.7, 2.8, 2.9, 3. , 3.1, 3.2, 3.3, 3.4, 3.5]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist([r["nGrover"][3] for r in results], range=(8, 11), bins=3)
# Out:
# (array([93.,  0.,  7.]),
#  array([ 8.,  9., 10., 11.]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist([r["nGrover"][4] for r in results], range=(18,25), bins=7)
# Out:
# (array([59.,  0., 33.,  0.,  1.,  0.,  6.]),
#  array([18., 19., 20., 21., 22., 23., 24., 25.]),
#  <BarContainer object of 7 artists>)
